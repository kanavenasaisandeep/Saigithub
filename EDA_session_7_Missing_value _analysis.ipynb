# %% [markdown]
# **How create a null values in a data**

# %%
import numpy as np
import pandas as pd

# %%
d={'Names':['Ramesh','Suresh',None,'Mahesh'],
    'Age':[None,22,24,25],
   'City':['Hyd','Blr','Pune',None]}
df1=pd.DataFrame(d)
df1
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2    None  24.0  Pune
# 3  Mahesh  25.0  None

# %%
d={'Names':['Ramesh','Suresh',None,'Mahesh'],
    'Age':[None,22,24,25],
   'City':['Hyd','Blr','Pune',None]}
df2=pd.DataFrame(d)
df2.to_csv('data2.csv',index=False)
df2
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2    None  24.0  Pune
# 3  Mahesh  25.0  None

# %%
- Categorical data use none
-

# %%
df1
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2    None  24.0  Pune
# 3  Mahesh  25.0  None

# %%
df1
df1.values
df1.dtypes
df1.isnull()
df1.isnull().sum()

# %%
df1
# Out:
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2    None  24.0  Pune
# 3  Mahesh  25.0  None

# %%
df1.values
# Out:
# array([['Ramesh', nan, 'Hyd'],
#        ['Suresh', 22.0, 'Blr'],
#        [None, 24.0, 'Pune'],
#        ['Mahesh', 25.0, None]], dtype=object)

# %%
df1.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df1.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False   True

# %%
df1.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %% [markdown]
# **Fill the values**

# %%
#Random fill
df1.fillna(30)
# Out:
#     Names   Age  City
# 0  Ramesh  30.0   Hyd
# 1  Suresh  22.0   Blr
# 2      30  24.0  Pune
# 3  Mahesh  25.0    30

# %%
# select one column and will with value
df1['City'].fillna('Delhi')
# Out:
# 0      Hyd
# 1      Blr
# 2     Pune
# 3    Delhi
# Name: City, dtype: object

# %%
df1.fillna(30)
df['City'].fillna('Delhi')

# %%
# pad,bfill,ffill,backfill
#axis=0 axis=1
df1.fillna(method='pad')
df1
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_21620\301331543.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='pad')
#     Names   Age  City
# 0  Ramesh   NaN   Hyd
# 1  Suresh  22.0   Blr
# 2    None  24.0  Pune
# 3  Mahesh  25.0  None

# %%
df1.fillna(method='pad',axis=1)
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_21620\1258234312.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='pad',axis=1)
#     Names     Age  City
# 0  Ramesh  Ramesh   Hyd
# 1  Suresh    22.0   Blr
# 2    None    24.0  Pune
# 3  Mahesh    25.0  25.0

# %%
df1.fillna(method='bfill')
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_21620\2259200643.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='bfill')
#     Names   Age  City
# 0  Ramesh  22.0   Hyd
# 1  Suresh  22.0   Blr
# 2  Mahesh  24.0  Pune
# 3  Mahesh  25.0  None

# %%
df1.fillna(method='bfill',axis=1)
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_14388\2900121331.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='bfill',axis=1)
#     Names   Age  City
# 0  Ramesh   Hyd   Hyd
# 1  Suresh  22.0   Blr
# 2    24.0  24.0  Pune
# 3  Mahesh  25.0  None

# %% [markdown]
# - mean
# - median
# - mode

# %%
age_mean=df1['Age'].mean()
df1['Age'].fillna(age_mean)
# Out:
# 0    23.666667
# 1    22.000000
# 2    24.000000
# 3    25.000000
# Name: Age, dtype: float64

# %%
# there is no particular rule how to fille the missing the values
# it is completely based on situation

# %%
Gender=['Male','Female',None]
d1=pd.DataFrame(Gender,columns=['Gender'])

# %%
d1 # i want to handover this data to my students with not encode
# Out:
#    Gender
# 0    Male
# 1  Female
# 2    None

# %%
d={'Female':0,'Male':1}
d1['Gender']=d1['Gender'].map(d)
d1
# Out:
#    Gender
# 0     1.0
# 1     0.0
# 2     NaN

# %%
#  the students think that i want to fill a missing
# data is numerical: mean
(1+0)/2
# Out:
# 0.5

# %% [markdown]
# **Situation:2**

# %%
# ML algorithm
# churn ; stay or not stay
churn=['stay','not_stay',None]
churn=[0,1,None]
churn=[0,1,0.5]

# %% [markdown]
# **situation:3**

# %%
# no of days
[20,25,np.nan,31]
(20+25+31)/3
# Out:
# 25.333333333333332

# %% [markdown]
# **situation:4**

# %%
course=['DS','AI','DS','Devops','AI','Devops','AI']
fee=[30000,2700,30000,22000,3000,22000,np.nan]
pd.DataFrame(course,fee)

# %% [markdown]
# **KNNImputer**

# %% [markdown]
# - KNN : K-nearest neighbours
# - where K is a number
# - instead of taking avg of all the values data
#    - first will find the neighbours who are close with missing data
#    - by using Euclidian distance calculation will identify the neighbour rows
#    - suppose k=2 will identify the two closest rows
#    - those closest rows values will take it,will calculate the mean
#    - finally will fill with the mean

# %%
salary=[50000,np.nan,70000,90000]
age=[25,28,30,40]
df=pd.DataFrame(zip(salary,age),columns=['Salary','Age'])
df
# Out:
#     Salary  Age
# 0  50000.0   25
# 1      NaN   28
# 2  70000.0   30
# 3  90000.0   40

# %% [markdown]
# - sklearn
#   - impute
#   - KNNImputer

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=2)
pd.DataFrame(imputer.fit_transform(df))
# Out:
#          0     1
# 0  50000.0  25.0
# 1  60000.0  28.0
# 2  70000.0  30.0
# 3  90000.0  40.0
